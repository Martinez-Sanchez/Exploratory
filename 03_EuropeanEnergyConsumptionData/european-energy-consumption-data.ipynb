# %% [markdown]
#  # ⚡ 🧑‍🎓 <span style='color:#953553'> European Energy Consumption Data </span> 🧑‍🎓 ⚡

# %% [markdown]
# ![Gita-editor-letter.jpg](attachment:578a46b1-24d4-4b5b-9e5c-7962979707bd.jpg)
#
# Image from https://www.imf.org/en/Publications/fandd/issues/2022/12/editor-letter-energy-security-and-the-path-to-green

# %% [markdown]
# <a id=TOC></a> <br>
# # <div style="text-align: Center; background-color:  #CBC3E3 ; font-family:cursive; color:  #953553; padding: 14px; line-height: 1;border-radius:20px"> Table of contents: </div>
#
# 1. [Introduction](#01)
#     1. [Data](#02)
#     1. [Goal](#03)
# 1. [Preparation](#04)
#     1. [Open the file](#05)
#     1. [Exploratory analysis](#06)
#     1. [Plotting time](#07)
#     1. [Correlation](#08)
# 1. [Solutions](#sol)
# 1. [Further exercises](#FurtherExercises)
# 1. [References](#references)

# %% [markdown]
# <a id=01></a> <br>
# # <div style="text-align: Right; background-color:#953553   ; font-family:cursive; color:  #CBC3E3; padding: 14px; line-height: 1;border-radius:20px"> 1. Introduction </div>
# [Table of contents](#TOC)

# %% [markdown]
# <a id=02></a> <br>
# # <div style="text-align: Left; background-color:  #CBC3E3 ; font-family:cursive; color:  #953553; padding: 14px; line-height: 1;border-radius:20px"> 1.a Data 🧾 </div>
# [Table of contents](#TOC)
#
# Are you ready for learning Python? This simple notebook could help you. I hope so! 🤞
#
# I found this csv file with three colums in the following url:
#
# 👉 URL Data: https://www.kaggle.com/datasets/deepikakoche/european-energy-consumption-data?select=EuroEnergy.csv
#
# As you can see, it does not have any information about the data set. It is not be useful for developing any conclusion about consumption of energy in Europe because it does not have any other information about the data set, such as: year, period, ... . But, it could be useful for learning Python. The data set has three columns: countries in Europe, gdp (Gross domestic product) and energy and twenty rows. It is a manageable file 😊

# %% [markdown]
# <a id="03"></a> <br>
#
# # <div style="text-align: Left; background-color:  #CBC3E3 ; font-family:cursive; color:  #953553; padding: 14px; line-height: 1;border-radius:20px"> 1.b Goal 🔎 </div>
# [Table of contents](#TOC)
#
# Our goal is learning Python.
#
# 👉 Importing modules.
#
# 👉 Asking information about the functions.
#
# 👉 Open a csv file and display the data in a DataFrame.
#
# 👉 Display general information about de DataFrame.
#
# 👉 Rename a column.
#
# 👉 Set index of the data frame.
#
# 👉 Display plots.
#
# 👉 Operating with data in order to display data information.
#
# 👉 Calculate correlation.

# %% [markdown]
# <a id="04"></a> <br>
# # <div style="text-align: Right; background-color:#953553   ; font-family:cursive; color:  #CBC3E3; padding: 14px; line-height: 1;border-radius:20px"> 2. Preparation 🛠️</div>
# [Table of contents](#TOC)
#
# 🔨 Firstly, the dataset is a CSV file. Wait! A CSV file? 🤔  Our data set is a CSV file, what is it mean? A CSV is a comma-separated values file, which allows data to be saved in a tabular format <a name="ref-1"/>[(Wikipedia CSV files)](#cite-CSV).
#
#
# 🔨 Secondly, we need see the information. So, we are to choose the tools for playing with this file and display the information. Our tools are inside the modules and we import one or another depend on the task you would like to perform with the data.
#
# ♻️ In the first part of the this notebook we are going to import Pandas (as pd, so each time we call the a function from Panda we will write: pd.function instead of pandas.function, save time ⏳) module which is a kind of Excel.

# %%
# Import modules
import pandas as pd

# %% [markdown]
# 😟 Wait!! I don't know how the functions inside the modules does! You always can ask information about the function with help():

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %% [markdown]
# <a id="05"></a> <br>
#
# # <div style="text-align: Left; background-color:  #CBC3E3 ; font-family:cursive; color:  #953553; padding: 14px; line-height: 1;border-radius:20px"> 2.a - Open the file 📖 </div>
# [Table of contents](#TOC)

# %% [markdown]
# **The file**: Where is your file stored? The data file name is "EuroEnergy.csv"  and it has been stored in the subfloder "input" which is inside a "kaggle" folder and the name of the file ("EuroEnergy.csv"): '/kaggle/input/european-energy-consumption-data/EuroEnergy.csv'
#
# **The function**: We need a function in order to display the information which is stored in the file.
#
# 1️⃣  Function read_csv from pandas module, which was imported in [2. Preparation](#04), stored as a csv file into a pandas DataFrame.
#
# 🛑 Data Frame? What is a DataFrame? 😨  According to Jake VanderPlas <a name="ref-2"/>[(Python Data Science Handbook)](#cite-PythonHandbook). _Recall that a DataFrame acts in many ways like a two-dimensional or structured array, and in other ways like a dictionary of Series structures sharing the same index._
#
# 📌 Importing data in Python data frame (we will call it "df") and print the type of df object and the first rows of the data frame.

# %%
# Import data in Python data frame 
#df = pd.read_csv('./data/EuroEnergy.csv')
df = pd.read_csv('/kaggle/input/european-energy-consumption-data/EuroEnergy.csv')

# Print the df type, it should by DataFrame
print(type(df))


# Print the first five rows of the DataFrame
print (df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
#   Unnamed: 0    gdp  energy
# 0    Austria  45451   30633
# 1    Belgium  62049   58894
# 2     Cyprus   2003    1211
# 3    Denmark  34540   27049
# 4    Finland  28388   26405

# %% [markdown]
#  💡1️Print last 3 rows  👉 <a name="ref-3"/>[(clue)](#cite-df.tail). [Solution](#sol01)

# %% [markdown]
# <a id="06"></a> <br>
#
# # <div style="text-align: Left; background-color:  #CBC3E3 ; font-family:cursive; color:  #953553; padding: 14px; line-height: 1;border-radius:20px"> 2.b - Exploratory analysis 👁️ </div>
# [Table of contents](#TOC)
#
# 📌 Display information about the data frame with the method df.info():

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  20 non-null     object
#  1   gdp         20 non-null     int64
#  2   energy      20 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 608.0+ bytes

# %% [markdown]
#  💡2️ The data frame has 3 colums ('Unnamed: 0', 'gdp', 'energy'), how many rows has DataFrame? 👉 [Solution](#sol02)
#
#  The column 'Unnamed: 0' has the name of the countries, we rename this column with the string 'Country'.

# %%
print(df.columns)
print('\n Renaming the column: Unnamed: 0 -> Country: \n')
df = df.rename(columns={'Unnamed: 0': 'Country'})
print(df.columns)
# Out:
# Index(['Country', 'gdp', 'energy'], dtype='object')
#
#  Renaming the column: Unnamed: 0 -> Country:
#
# Index(['Country', 'gdp', 'energy'], dtype='object')

# %% [markdown]
# We are going to set the column with the countries' names as index

# %%
df = df.set_index('Country', drop=True)

# %% [markdown]
# 📌 Display information maximun and mininum energy values:

# %%
#first we choose the column 'energy'
df['energy']
# Out:
# Country
# Austria         30633
# Belgium         58894
# Cyprus           1211
# Denmark         27049
# Finland         26405
# France         233907
# Greece          20119
# Iceland          1124
# Ireland         11053
# Italy          192453
# Malta             456
# Netherlands     84416
# Norway          26086
# Portugal        12080
# Spain           88148
# Sweden          45132
# Switzerland     23234
# Turkey          32619
# UK             268056
# WGermany       352677
# Name: energy, dtype: int64

# %%
# selecting the maximun value of the energy column
df['energy'].max()

# Display the row which has the maximun energy consumation in Europe
df[df['energy'] == df['energy'].max()]
# Out:
#              gdp  energy
# Country
# WGermany  428888  352677

# %%
# selecting the minimun value of the energy column
df['energy'].min()
# Display the row which has the minimun energy consumation in Europe
df[df['energy'] == df['energy'].min()]
# Out:
#           gdp  energy
# Country
# Malta    1251     456

# %% [markdown]
#  💡3️ WGermany and Malta are the European Country which have the maximun and minimun consumation of energy values. Which is the country with less gdp? 👉 [Solution](#sol03)

# %% [markdown]
# <a id="07"></a> <br>
#
# # <div style="text-align: Left; background-color:  #CBC3E3 ; font-family:cursive; color:  #953553; padding: 14px; line-height: 1;border-radius:20px"> 2.c - Plotting time 📊 </div>
# [Table of contents](#TOC)
#
# 📌 Display graph information.
#
# The easier way to plot the information is with df.plot()

# %%
#The whole data frame, the X-axis is index values
df.plot()
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
#  💡4️ Could you display the information of 'energy' column? 👉 [Solution](#sol04)
#
#  We can select other kind of graphic for display the information. Shall we select a bar chart? The information about the bar chart is 👇

# %%
help(df.plot.bar())
# Out:
# Help on Axes in module matplotlib.axes._axes object:
#
# class Axes(matplotlib.axes._base._AxesBase)
#  |  Axes(fig, *args, facecolor=None, frameon=True, sharex=None, sharey=None, label='', xscale=None, yscale=None, box_aspect=None, **kwargs)
#  |
#  |  An Axes object encapsulates all the elements of an individual (sub-)plot in
#  |  a figure.
#  |
#  |  It contains most of the (sub-)plot elements: `~.axis.Axis`,
#  |  `~.axis.Tick`, `~.lines.Line2D`, `~.text.Text`, `~.patches.Polygon`, etc.,
#  |  and sets the coordinate system.
#  |
#  |  Like all visible elements in a figure, Axes is an `.Artist` subclass.
#  |
#  |  The `Axes` instance supports callbacks through a callbacks attribute which
#  |  is a `~.cbook.CallbackRegistry` instance.  The events you can connect to
#  |  are 'xlim_changed' and 'ylim_changed' and the callback will be called with
#  |  func(*ax*) where *ax* is the `Axes` instance.
#  |
#  |  .. note::
#  |
# ...

# %%
axes = df.plot.bar(rot=90, subplots=True)
axes[1].legend(loc=2)

# %% [markdown]
# 🤔 Shall we improve? We are going to display an horizontal bar plot which show the percentage over the total energy consumption in Europe per country. But first we need to calculate the total energy consumption in Europe.

# %%
##Calculate percentage of energy source

# Calculate the sum of each column.
df_general = df.sum(axis=0)

# Quotient of each country by the sum of all countries, multiplican by 100.
df_percentage = (df/df_general.sum())*100

# Sorting energy values ascending
df_percentage.sort_values(by='energy', ascending=True, inplace=True)

# Display de horizontal bar plot
df_percentage['energy'].plot.barh()
# Out:
# <Axes: ylabel='Country'>

# %% [markdown]
# The result is consistent with the result of maximun and minimun energy values, is not it?
#
#  💡5️ Try to plot the vertical plot with the data of the 'gdp' column? 👉 [Solution](#sol05)

# %% [markdown]
# <a id="08"></a> <br>
#
# # <div style="text-align: Left; background-color:  #CBC3E3 ; font-family:cursive; color:  #953553; padding: 14px; line-height: 1;border-radius:20px"> 2.d - Correlation 📈 </div>
# [Table of contents](#TOC)
#
# 📌 Are energy and gdp correlated? According with the scatter plot 👇 ... could be!

# %%
df.plot.scatter(x='energy', y='gdp')
# Out:
# <Axes: xlabel='energy', ylabel='gdp'>

# %%
# Pearson's r
print( 'Pearson:', df['energy'].corr(df['gdp']))
# Spearman's rho
print( 'Spearman:', df['energy'].corr(df['gdp'], method='spearman') )
# Out:
# Pearson: 0.9774850575035166
# Spearman: 0.956390977443609

# %% [markdown]
# The pearson coeficient near 1 tell us the strong correlation between the energy and the gdp.
#
# 💡6️ Calculate the Kendall's tau 👉 [Solution](#sol06)

# %% [markdown]
# <a id=sol></a> <br>
# # <div style="text-align: Right; background-color:#953553   ; font-family:cursive; color:  #CBC3E3; padding: 14px; line-height: 1;border-radius:20px">4. Solutions </div>
# [Table of contents](#TOC)

# %% [markdown]
# <a id=sol01></a> <br>
# 1️⃣ Print last 3 rows:

# %%
df.tail(3)
# Out:
#    Unnamed: 0     gdp  energy
# 17     Turkey   91946   32619
# 18         UK  279191  268056
# 19   WGermany  428888  352677

# %% [markdown]
# <a id=sol02></a> <br>
# 2️ The data frame has 3 colums, how many row has it? we use the df.shape displays DataFrame's dimensinality.
# - The first value is the number of rows
# - The second the number of columns:

# %%
df.shape
# Out:
# (20, 3)

# %%
#Dimensionality (rows, columns) of the DataFrame
print(df.shape)

print('Display df.shape type: {0} '.format(type(df.shape)))

#Display the first element of the tuple df.shape - rows
print('Number or rows: {0}'.format(df.shape[0]))

#Display the second element of the tuple df.shape - columns
print('Number or columns: {0}'.format(df.shape[1]))
# Out:
# (20, 3)
# Display df.shape type: <class 'tuple'>
# Number or rows: 20
# Number or columns: 3

# %% [markdown]
# <a id=sol03></a> <br>
# 3️  Which is the country with lower gdp? Malta, right?

# %%
#Display the'Unnamed: 0' element of the dataFrame
df[df['gdp'] == df['gdp'].min()]
# Out:
#           gdp  energy
# Country
# Malta    1251     456

# %% [markdown]
# <a id=sol04></a> <br>
# 4️ Could you display the information of 'energy' column?

# %%
# Plotting only one column, the X-axis is the index values
df['energy'].plot()
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# <a id=sol05></a> <br>
#  💡5️ Try to plot the vertical plot for 'gdp' column?

# %%
#df_percentage.sort_values(ascending=False, inplace=True)
df_percentage.sort_values(by='gdp', ascending=False, inplace=True)
#help(df_percentage.sort_values)
df_percentage['gdp'].plot.bar()
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# <a id=sol06></a> <br>
# 6️ Calculate the Kendall's tau

# %%
df['energy'].corr(df['gdp'], method='kendall')
# Out:
# 0.8736842105263158

# %% [markdown]
# <a id=FurtherExercises></a> <br>
# # <div style="text-align: Right; background-color:#953553   ; font-family:cursive; color:  #CBC3E3; padding: 14px; line-height: 1;border-radius:20px"> Further exercises </div>
# [Table of contents](#TOC)
# https://www.kaggle.com/code/martinezsanchez/eurovision-song-contest-winners-1956-2022

# %% [markdown]
# <a id=references></a> <br>
# # <div style="text-align: Right; background-color:#953553   ; font-family:cursive; color:  #CBC3E3; padding: 14px; line-height: 1;border-radius:20px"> References </div>
# [Table of contents](#TOC)

# %% [markdown]
# ><a name="cite-CSV"/><sup>[^](#ref-1)  </sup>Wikipedia CSV files. https://en.wikipedia.org/wiki/Comma-separated_values
#
# ><a name="cite-PythonHandbook"/><sup>[^](#ref-2)  </sup>
# Jake. VanderPlas,
# Python data science handbook: essential tools for working with data,
# New York : O'Reilly Media,
# 2017,
# ISBN  978-1-491-91205-8,
# (https://www.oreilly.com/library/view/python-data-science/9781491912126/)
#
# ><a name="cite-df.tail"/><sup>[^](#ref-3)  </sup>Data Frame last rows. https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.tail.html

# %% [markdown]
# First version 25/06/2023

# %% [markdown]
# ## Thanks for reading! 🐸
